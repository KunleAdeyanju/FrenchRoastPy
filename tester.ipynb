# %%
from customer import customers

# %%
cc = customers('/Users/kunle/Python Projects/FrenchRoastPy/resources/transactions.csv').create_dataframe()
#cc.create_dataframe()
cc
# Out:
#        transactionId  customerId  accountId transactionType  amount  \
# 0                  1         103      10000      withdrawal  714.25
# 1                  2         109      10000      withdrawal  750.34
# 2                  3         117      10000         deposit  514.15
# 3                  4         106      10001         deposit  364.60
# 4                  5         119      10001         deposit  798.86
# ...              ...         ...        ...             ...     ...
# 19995          19996         103      10000      withdrawal  967.17
# 19996          19997         117      10001      withdrawal  759.20
# 19997          19998         100      10000         deposit  659.53
# 19998          19999         116      10001      withdrawal  399.74
# 19999          20000         107      10002         deposit  395.32
#
#                           timestamp
# 0      Fri Dec 06 12:30:05 EST 2013
# 1      Tue Mar 27 08:18:12 EDT 2012
# 2      Sat Mar 25 21:17:25 EDT 2017
# ...

# %%
dd = cc.groupby(['customerId', 'transactionType','accountId']).sum('amount')

# %%
dd.drop(columns='transactionId', inplace=True)

# %%
dd
# Out:
#                                         amount
# customerId transactionType accountId
# 100        deposit         10000      81194.15
#                            10001      90442.02
#                            10002      86412.78
#            withdrawal      10000      83071.10
#                            10001      93642.50
# ...                                        ...
# 120        deposit         10001      95742.70
#                            10002      98705.29
#            withdrawal      10000      94046.37
#                            10001      87629.53
#                            10002      83499.08
#
# [126 rows x 1 columns]

# %%
for i in dd.index:
    if dd.loc[i][t]
# Out:
# {'amount': {(100, 'deposit', 10000): 81194.15,
#   (100, 'deposit', 10001): 90442.02,
#   (100, 'deposit', 10002): 86412.78,
#   (100, 'withdrawal', 10000): 83071.1,
#   (100, 'withdrawal', 10001): 93642.5,
#   (100, 'withdrawal', 10002): 82959.45,
#   (101, 'deposit', 10000): 77883.89,
#   (101, 'deposit', 10001): 72093.04,
#   (101, 'deposit', 10002): 94000.62,
#   (101, 'withdrawal', 10000): 86445.77,
#   (101, 'withdrawal', 10001): 108655.69,
#   (101, 'withdrawal', 10002): 101660.94,
#   (102, 'deposit', 10000): 88451.9,
#   (102, 'deposit', 10001): 90293.56,
#   (102, 'deposit', 10002): 84224.24,
#   (102, 'withdrawal', 10000): 90043.01,
#   (102, 'withdrawal', 10001): 81968.41,
#   (102, 'withdrawal', 10002): 90784.93,
#   (103, 'deposit', 10000): 90775.63,
#   (103, 'deposit', 10001): 86905.48,
#   (103, 'deposit', 10002): 93163.2,
#   (103, 'withdrawal', 10000): 100452.61,
#   (103, 'withdrawal', 10001): 80755.23,
#   (103, 'withdrawal', 10002): 91457.21,
# ...

# %%
for i
